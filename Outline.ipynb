# %% [markdown]
# # **Hands-On Machine Learning Lightning Tour**
# ## Part 1 - Data to Model Evaluation

# %%
from IPython import display 
display.Image("./images/basicprocess.png")

# %% [markdown]
# #### Data Failures
# 1. Missing Data
# 1. Outliers
# 1. Wrong format
# 1. Useless
# 1. Erronous/deceptive
# 1. Sparse
# 1. Bias
# 1. Static
# ## **Linear Relationship** between integer Values - *Linear Regression*
# ## **Classification** based on multiple values - *Random Forest*
# ## **Clustering** based on multiple Values - *K Means Clustering*
# ## **Classification** based on many Categories and integer Values - *Artificial Neural Network*

# %% [markdown]
# # Start Listener for Data Selections

# %%
# %run -i mlLiveService.py
# Out:
# starting server...
#  * Serving Flask app 'mlLiveService' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://172.17.0.2:5000/ (Press CTRL+C to quit)
# 192.168.2.70 - - [03/Sep/2021 14:45:44] "GET /dataselect?independent=9&dependent=10 HTTP/1.1" 200 -
# Selection:  9
# On average, how many hours per week do you spend coding?
# Selected Names:  ['On average, how many hours per week do you spend coding?']
# LENGTH:  82  Shape:  (82, 1)
# COMPLETED DATASET SHAPE:  (82, 1)
# Data Shape:  (82, 1)
# ind___ 9
# dep___ 10
# Selection:  10
# On average, how many hours each week do you exercise?
# Selected Names:  ['On average, how many hours each week do you exercise?']
# LENGTH:  82  Shape:  (82, 1)
# ...
